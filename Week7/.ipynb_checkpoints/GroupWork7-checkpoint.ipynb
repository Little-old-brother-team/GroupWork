# %% [markdown]
# ## Assignment Week 7

# %% [markdown]
# 1. Use your eigenproblem solver to find the eigenvalues of the matrix
# $$
# A =\begin{pmatrix}
# −2 &+2 &−3\\
# +2 &+1 &−6\\
# −1 &−2 &+0
# \end{pmatrix}
# $$
# (1) Verify that you obtain the eigenvalues $\lambda_1 = 5$, $\lambda_2 = \lambda_3 = −3$. Notice that double roots can cause problems. In particular, there is a uniqueness issue with their eigenvectors because any combination of these eigenvectors is also an eigenvector.
# (2) Verify that the eigenvector for $λ_1 = 5$ is proportional to
# $$
# x_1 = \frac{1}{\sqrt{6}}\begin{pmatrix}
# −1 \\ −2 \\+1\end{pmatrix}
# $$
# (3) The eigenvalue −3 corresponds to a double root. This means that the corresponding eigenvectors are degenerate, which in turn means that they are not unique. Two linearly independent ones are
# $$
# x_2 = \frac{1}{\sqrt{5}}\begin{pmatrix}
# −2\\ +1\\0\end{pmatrix},\quad
# x_3 = \frac{1}{\sqrt{10}}\begin{pmatrix}
# 3\\ 0\\1\end{pmatrix}
# $$
# In this case, it is not clear what your eigenproblem solver will give for the eigenvectors. Try to find a relationship between your computed eigenvectors with the eigenvalue −3 and these two linearly independent ones.
# (Hint：Please read the sample program `Eigen.ipynb` for your reference)

# %%
import numpy as np
from numpy.linalg import eig

A = np.array([[-2,2,-3],[2,1,-6],[-1,-2,0]])
Es, evectors = eig(A) # Solves eigenvalue and eigenvectors by linalg
print("The eigenvalue calculated by linalg is: {}\n".format(Es))
print("Agree with the theoretical result.\n")

# Then check the eigenvector for lambda = 5.
Ev5 = np.transpose(evectors)[1]
print("The ratio of the eigenvector for lambda = 5 is: {}\n".format(np.array([-1,-Ev5[1]/Ev5[0],-Ev5[2]/Ev5[0]])))
print("The eigenvector for λ = 5 is proportional to x1\n")

# Decompose the other two eigenvector as a linear combination of x2 and x3.
x2 = np.array([-2,1,0]/np.sqrt(5))
x3 = np.array([3,0,1]/np.sqrt(10)) # Only needs the first two value.
X = np.transpose(np.array([x2[0:2],x3[0:2]]))
Ev2 = np.transpose(evectors)[0]
Ev3 = np.transpose(evectors)[2]
coeff2 = np.linalg.solve(X,Ev2[0:2]) # Solve the linear equation X*coeff = y
coeff3 = np.linalg.solve(X,Ev3[0:2]) 
print('The first eigenvector of -3 {} equals {:.4f} x2 + {:.4f} x3 = {}\n'.format(Ev2,coeff2[0],coeff2[1],coeff2[0]*x2+coeff2[1]*x3))
print('The second eigenvector of -3 {} equals {:.4f} x2 + {:.4f} x3 = {}\n'.format(Ev3,coeff3[0],coeff3[1],coeff3[0]*x2+coeff3[1]*x3))
# Out:
# The eigenvalue calculated by linalg is: [-3.  5. -3.]
#
# Agree with the theoretical result.
#
# The ratio of the eigenvector for lambda = 5 is: [-1. -2.  1.]
#
# The eigenvector for λ = 5 is proportional to x1
#
# The first eigenvector of -3 [-0.95257934  0.27216553 -0.13608276] equals 0.6086 x2 + -0.4303 x3 = [-0.95257934  0.27216553 -0.13608276]
#
# The second eigenvector of -3 [-0.02296692  0.83534731  0.54924256] equals 1.8679 x2 + 1.7369 x3 = [-0.02296692  0.83534731  0.54924256]

# %% [markdown]
# 2. Please fit the Millikan data (as shown in the table) directly to a linear function
#     $$
#     q_k=ke\pm\Delta q_k
#     $$
#     and analyze the accuracy of the approximation. Assume that
#
#     (1) the error bars $\Delta {q_k}$ in the experimental measurements is a constant as $\Delta q$.
#
#     (2) Different $\Delta {q_k}$ with $\left\vert\Delta {q_k}\right\vert= 0.05q_k$.

# %% [markdown]
#  $k$   | 4     | 5     | 6     | 7     | 8     | 9     | 10    | 11    |
#  :---- | :---- | :---- | :---- | :---- | :---- | :---- | :---- | :---- |
#  $q_k$ | 6.558 | 8.206 | 9.880 | 11.50 | 13.14 | 14.82 | 16.40 | 18.04 |
#
#  $k$   | 12    | 13    | 14    | 15    | 16    | 17    | 18    |
#  :---- | :---- | :---- | :---- | :---- | :---- | :---- | :---- |
#  $q_k$ | 19.68 | 21.32 | 22.96 | 24.60 | 26.24 | 27.88 | 29.52 |

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
k = np.arange(4,19)
qk = np.array([6.558,8.206,9.880,11.50,13.14,14.82,16.40,18.04,19.68,21.32,22.96,24.60,26.24,27.88,29.52])

# %% [markdown]
# $$
# \chi^2 = \sum_{i=1}^N\left(\frac{q_k^{(i)}-ek_i}{\Delta q_k}\right)^2
# $$
# **(1)** when $\Delta q_k$ is constant,
# $$
# 0 = \frac{\partial \chi^2}{\partial e} = -2\sum_{i=1}^N\frac{q_k^{(i)}-ek_i}{\Delta q_k^2}
# $$
# get
# $$
# e = \frac{\sum_{i=1}^Nq_k^{(i)}}{\sum_{i=1}^Nk_i}
# $$

# %%
e = np.sum(qk)/np.sum(k)
plt.plot(k,qk,'o')
plt.plot(k,e*k)
plt.show()
deltaqk2 = np.sum((qk-e*k)**2)/(len(k)-1)
chi1_square = np.sum( (qk - e*k)**2 )
R1_square = 1 - np.sum( (qk - e*k)**2 ) / np.sum((qk-np.mean(qk))**2)
print(f'chi^2 = {chi1_square/deltaqk2}')
print(f'  R^2 = {R1_square}')
# Out:
# chi^2 = 14.0
#   R^2 = 0.9999923990911664

# %% [markdown]
# $\chi^2$接近N-m，$R^2$非常接近1，近似精确度较高

# %% [markdown]
# **(2)** if $\left\vert\Delta {q_k}\right\vert= 0.05q_k$,
# $$
# 0 = \frac{\partial \chi^2}{\partial e} = -2\sum_{i=1}^N\frac{q_k^{(i)}-ek_i}{\Delta q_k^2} =  -800\sum_{i=1}^N\frac{q_k^{(i)}-ek_i}{q_k^{(i)2}}
# $$

# %% [markdown]
# $$
# e = \frac{\sum_{i = 1}^N1/q_k^{(i)}}{\sum_{i = 1}^Nk_i/q_k^{(i)}}
# $$

# %%
e = np.sum(1/qk)/np.sum(k/qk**2)
error_range = [0.05*qk,0.05*qk]
plt.errorbar(k,qk,fmt = 'o',yerr = error_range,mec='salmon')
plt.plot(k,e*k)
plt.show()
chi2_square = np.sum( (qk - e*k)**2 / (0.05*qk)**2 )
R2_square = 1 - np.sum( (qk - e*k)**2 ) / np.sum((qk-np.mean(qk))**2)
print(f'chi^2 = {chi2_square}')
print(f'  R^2 = {R2_square}')
# Out:
# chi^2 = 0.01204864432182769
#   R^2 = 0.9999894602155894

# %% [markdown]
# $\chi^2$接近0，$R^2$非常接近1，近似精确度较高

# %% [markdown]
# 3. Derive the linearization form for each of the following functions:
#     $$
#     \begin{array}{llll}
#     (1) &y=\dfrac{A}{x}+B  &    (2) &y=\dfrac{D}{x+C}\\
#     (3) &y=\dfrac{1}{Ax+B} &    (4) &y=\dfrac{x}{A+Bx}\\
#     (5) &y=A\ln x+B &      (6)& y=Cx^{A}\\
#     (7) &y=\left( Ax+B\right) ^{-2} &   (8) & y=Cxe^{-Dx}
#     \end{array}
#     $$

# %% [markdown]
# $$
# \begin{array}{llll}
# (1) &y = A\left(\frac{1}{x}\right)+B  & (2) &\frac{1}{y} = \frac{x}{D}+\frac{C}{D}\\
# (3) &\frac{1}{y} = Ax+B &    (4) &\frac{1}{y} = A\frac{1}{x}+B\\
# (5) &y = A(\ln x) + B &    (6) &\ln y = A\ln x +\ln C\\
# (7) &\frac{1}{y^{1/2}} = Ax + B &    (8) &\ln{\frac{y}{x}} = -Dx+\ln C
# \end{array}
# $$

# %% [markdown]
# 4. In 1929 Edwin Hubble examined the data in the table relating the radial velocity $v$ of 24 extra galactic nebulae to their distance $r$ from our galaxy[^Hubble]. Although there was considerable scatter in the data, he fit them with a straight line:
#     $$
#     v = Hr
#     $$
#     where $H$ is now called the Hubble constant.
#
#     (1) Plot the data to verify the appropriateness of a linear relation
#     $$
#     v(r) \approx a + Hr
#     $$
#     (2) Deduce a value for the error $\sigma_i$ for each point as how much the histogram values appear to fluctuate about a smooth curve.
#     (3) Compute a least-squares straight-line fit to these data.
#     (4) Plot your fit on the curve with the data.
#     (5) After fitting the data, compute the variance and verify that approximately     one-third of the points miss the $\sigma$ error band (that’s what is expected for a
#     random distribution of errors).
#     (6) Determine the $\chi^2$ of the fit and comment on its value.
#     [^Hubble]: Hubble, E. (1929), A relation between distance and radial velocity among extra-galactic nebulae, Proc. Nat. Academy of Sciences of the United States of America, 15, 168-173.

# %% [markdown]
# | Object | $r$ | $v$ (km/s) |  Object| $r$ | $v$ (km/s) |Object| $r$ | $v$ (km/s) |
# | --- | --- |  --- | --- | --- | --- |  --- | --- | --- |
# |-| 0.032 | 170  | 3627 |0.9 | 650 |-| 0.034 |290|
# |4826| 0.9 |150| 6822| 0.214| -130|4649| 2.0| 1090|
# |5236 |0.9| 500| 598| 0.263| -70|1068| 1.0 |920|
# |221| 0.275 |-185 |5055 |1.1 |450|224| 0.275| -220|
# |7331| 1.1| 500| 5457| 0.45| 200|4258 |1.4| 500|
# |4736| 0.5| 290| 4141| 1.7| 960|5194| 0.5 |270|
# |4382 |2.0 |500 |4449 |0.63 |200|4472 |2.0| 850|
# |4214 |0.8 |300 |4486| 2.0 |800|3031| 0.9| -30|

# %%
# 1) plot the v-r
import numpy as np
import matplotlib.pyplot as plt

r_list = np.array([0.032, 0.9, 0.9, 0.275, 1.1, 0.5, 2.0, 0.8, 0.9, 0.214, 0.263, 1.1, 0.45, 1.7, 0.63, 2.0, 0.034, 2.0, 1.0, 0.275, 1.4, 0.5, 2.0, 0.9])
v_list = np.array([170, 150, 500, -185, 500, 290, 500, 300, 650, -130, -70, 450, 200, 960, 200, 800, 290, 1090, 920, -220, 500, 270, 850, -30])
plt.figure()
plt.scatter(r_list, v_list)
plt.title("1) Speed versus distance")
plt.xlabel("distance Mpc")
plt.ylabel("speed km/s")
plt.show()

# %% [markdown]
# 2) 3) and 4)
# First calculate $H_0$ with no error($\sigma_i = 0$), then assume $\sigma_i$ is the differences between $v_i$ and $H_0 r_i$.Then recalculate the $H$ and $a$

# %%
H0 = np.sum(v_list)/np.sum(r_list)
sigma = np.abs(v_list - H0 * r_list)

r_bar = np.sum(r_list/(sigma**2)) / np.sum(1/sigma**2)
v_bar = np.sum(v_list/(sigma**2)) / np.sum(1/sigma**2)

H = np.sum((r_list - r_bar) * v_list / sigma**2) / np.sum((r_list - r_bar) * r_list / sigma**2)
a = v_bar - H * r_bar
r_fit = np.linspace(0, 2, 21)
v_fit = a + H * r_fit
v_predict = a + r_list * H
error = np.sqrt(np.mean((v_list - v_predict)**2))

print(f"Hubble constant is {H:.3f},a ={a} with error {error:.3f}")

plt.figure()
plt.scatter(r_list, v_list, label='data')
plt.plot(r_fit, v_fit, c=(1,0.5,0), label='fit')
plt.title("1) Speed versus distance")
plt.xlabel("distance Mpc")
plt.ylabel("speed km/s")
plt.legend()
plt.show()
# Out:
# Hubble constant is 398.769,a =11.35765182756586 with error 225.731

# %%
# 5)
sigma_f = np.sqrt(np.mean((v_list - v_predict)**2))
in_or_not = np.abs(v_list-v_predict) - sigma_f
count = 0
for i in in_or_not:
    if i > 0:
        count += 1
print(f'rate of the points miss the error band :{count/len(in_or_not)}')
# Out:
# rate of the points miss the error band :0.4166666666666667

# %%
# 6)
chi_square = np.sum(((v_list - v_predict)/sigma)**2)
print(f'chi_square = {chi_square}')
print(f'N - m = {len(v_list) - 2}')
# Out:
# chi_square = 22.419724756585694
# N - m = 22

# %% [markdown]
# as we can see $\chi^2 \approx N-m$, it's not a bad fit

# %% [markdown]
# 5. Measurements of thermal conductivity, $\kappa$(W/mK) , of silicon at various temperatures, $T (K)$, are given as follows:
#
# | $T$ (K)         | 50   | 100  | 150  | 200  | 400  | 600  | 800  | 1000 |
# | --------------- | ---- | ---- | ---- | ---- | ---- | ---- | ---- | ---- |
# | $\kappa$ (W/mK) | 28   | 9.1  | 4.0  | 2.7  | 1.1  | 0.6  | 0.4  | 0.3  |

# %% [markdown]
# The data is to be fitted with a function of the form $\kappa=f(T)$. Determine which of the nonlinear equations: power function, exponential function, saturation function, can best fit the data and determine its parameters. Make a plot that shows the data points and the theoretical values.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
T = np.array([50,100,150,200,400,600,800,1000])
kappa = np.array([28,9.1,4.0,2.7,1.1,0.6,0.4,0.3])
# Plot the original
ax = plt.subplot(221)
plt.plot(T,kappa)
ax.set_title("Original T and kappa")
plt.tight_layout()

# First check exponential function
lnT = np.log(T)
lnKappa = np.log(kappa)
ax = plt.subplot(222)
ax.set_title("Exponential function")
plt.plot(lnT,kappa)

# Then power function
ax = plt.subplot(223)
ax.set_title("Power function")
plt.plot(lnT,lnKappa)
plt.tight_layout()

# Then saturation function
T_1 = 1 / T
kappa_1 = 1 / kappa
ax = plt.subplot(224)
ax.set_title("Saturation function")
plt.plot(T_1,kappa_1)
plt.tight_layout()

plt.show()
print("Obviously, power function performs the best.")
# Out:
# Obviously, power function performs the best.

# %%
# Now fit Y = bX + ln(a), where Y = lnKappa, X = lnT.
Y_mean = np.mean(lnKappa)
X_mean = np.mean(lnT)
b = np.sum((lnT-X_mean)*lnKappa) / np.sum((lnT-X_mean)*lnT)
lnA = Y_mean - X_mean*b

# Then calculate the theoretical value and plot together with raw data.
theoretical_linear = lnT * b + lnA
theoretical_power = np.exp(theoretical_linear)

plt.subplot(121)
plt.plot(T,theoretical_power)
plt.scatter(T,kappa)
plt.title("kappa vs T")
plt.xlabel("T")
plt.ylabel("kappa")

plt.subplot(122)
plt.plot(lnT,theoretical_linear)
plt.scatter(lnT,lnKappa)
plt.title("lnKappa vs lnT")
plt.xlabel("lnT")
plt.ylabel("lnKappa")
plt.tight_layout()

plt.show()

# %% [markdown]
# 6. Please complete your review of the numerical method and python programming. More details can be found in the file CP_review_202004.pdf(.md).
